# %%
import pandas as pd
# pd.read_parquet("/Users/scott.mckean/Desktop/3W/0/WELL-00001_20170201010207.parquet")
pd.read_parquet("/Users/scott.mckean/Desktop/3W/6/WELL-00002_20140212160333.parquet").reset_index(drop=False)
# Out:
#                 timestamp  ABER-CKGL  ABER-CKP  ESTADO-DHSV  ESTADO-M1  \
# 0     2014-02-12 16:03:33        NaN       NaN          NaN        NaN
# 1     2014-02-12 16:03:34        NaN       NaN          NaN        NaN
# 2     2014-02-12 16:03:35        NaN       NaN          NaN        NaN
# 3     2014-02-12 16:03:36        NaN       NaN          NaN        NaN
# 4     2014-02-12 16:03:37        NaN       NaN          NaN        NaN
# ...                   ...        ...       ...          ...        ...
# 27965 2014-02-12 23:49:38        NaN       NaN          NaN        NaN
# 27966 2014-02-12 23:49:39        NaN       NaN          NaN        NaN
# 27967 2014-02-12 23:49:40        NaN       NaN          NaN        NaN
# 27968 2014-02-12 23:49:41        NaN       NaN          NaN        NaN
# 27969 2014-02-12 23:49:42        NaN       NaN          NaN        NaN
#
#        ESTADO-M2  ESTADO-PXO  ESTADO-SDV-GL  ESTADO-SDV-P  ESTADO-W1  ...  \
# ...

# %%
from src.file_processing import read_nested_parquet_files

all_data = read_nested_parquet_files("/Users/scott.mckean/Desktop/3W")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.file_processing import read_nested_parquet_files
# ----> 3 all_data = read_nested_parquet_files("/Users/scott.mckean/Desktop/3W")
#
# File ~/Repos/hydrate_prediction/src/file_processing.py:33, in read_nested_parquet_files(root_dir, pattern)
#      30 for parquet_file in root_dir.rglob(pattern):
#      31     try:
#      32         # Read each parquet file
# ---> 33         df = pd.read_parquet(parquet_file).reset_index(drop=False)
#      34         # Add source file information
#      35         df["source_file"] = str(parquet_file)
#
# File ~/Repos/multimodal-accelerator/.venv/lib/python3.11/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
# ...

# %%
is_drawn = all_data.source_file.str.contains('DRAWN')
is_simulated = all_data.source_file.str.contains('SIMULATED')

# %%
real_data = all_data[~is_drawn & ~is_simulated]

# %%
real_no_class = real_data['class'].isna()
real_no_timestamp = real_data['timestamp'].isna()
clean_data = real_data[~real_no_class & ~real_no_timestamp].copy()

# %%
clean_data['well_number'] = clean_data['source_file'].str.extract(r'WELL-(\d+)').astype(int)

# %%
clean_data['source_file'] = clean_data['source_file'].str.replace('/Users/scott.mckean/Desktop', '')

# %%
clean_data.to_parquet('/Users/scott.mckean/Desktop/3w_compiled_data.parquet')
